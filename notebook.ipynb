# %%
import json
with open('data.json', mode='r') as file:
    data = json.load(file)

miss_data = [x for x in data if 'geolocation' not in x.keys()]

print(len(miss_data))
print (miss_data)
# Out:
# 12
# [{'name': 'Bulls Run', 'id': '5163', 'nametype': 'Valid', 'recclass': 'Iron?', 'mass': '2250', 'fall': 'Fell', 'year': '1964-01-01T00:00:00.000'}, {'name': 'Clohars', 'id': '5383', 'nametype': 'Valid', 'recclass': 'L4', 'mass': '48.6', 'fall': 'Fell', 'year': '1822-01-01T00:00:00.000'}, {'name': 'Jalanash', 'id': '12068', 'nametype': 'Valid', 'recclass': 'Ureilite', 'mass': '700', 'fall': 'Fell', 'year': '1990-01-01T00:00:00.000'}, {'name': 'Jemlapur', 'id': '12079', 'nametype': 'Valid', 'recclass': 'L6', 'mass': '450', 'fall': 'Fell', 'year': '1901-01-01T00:00:00.000'}, {'name': 'Cumulus Hills 04075', 'id': '32531', 'nametype': 'Valid', 'recclass': 'Pallasite', 'mass': '9.6', 'fall': 'Found', 'year': '2003-01-01T00:00:00.000'}, {'name': 'Maria Linden', 'id': '15418', 'nametype': 'Valid', 'recclass': 'L4', 'mass': '114', 'fall': 'Fell', 'year': '1925-01-01T00:00:00.000'}, {'name': 'Natal', 'id': '16923', 'nametype': 'Valid', 'recclass': 'Stone-uncl', 'mass': '1.4', 'fall': 'Fell', 'year': '1973-01-01T00:00:00.000'}, {'name': 'Niger (L6)', 'id': '16974', 'nametype': 'Valid', 'recclass': 'L6', 'mass': '3.3', 'fall': 'Fell', 'year': '1967-01-01T00:00:00.000'}, {'name': 'Niger (LL6)', 'id': '16975', 'nametype': 'Valid', 'recclass': 'LL6', 'mass': '3.3', 'fall': 'Fell', 'year': '1967-01-01T00:00:00.000'}, {'name': 'Dominion Range 03239', 'id': '32591', 'nametype': 'Valid', 'recclass': 'L6', 'mass': '69.5', 'fall': 'Found', 'year': '2002-01-01T00:00:00.000'}, {'name': 'Dominion Range 03240', 'id': '32592', 'nametype': 'Valid', 'recclass': 'LL5', 'mass': '290.89999999999998', 'fall': 'Found', 'year': '2002-01-01T00:00:00.000'}, {'name': 'Talampaya', 'id': '23791', 'nametype': 'Valid', 'recclass': 'Eucrite-cm', 'mass': '1421', 'fall': 'Fell', 'year': '1995-01-01T00:00:00.000'}]

# %%
for record in data:
    if 'mass' not in record.keys():
        record.update({'mass':'na'})
    elif 'year' not in record.keys():
        record.update({'year':'na'})

# %%
c = 0
for record in data:
    for v in record['geolocation'].items():
        c += 1
        print(c, v)
# Out:
# 1 ('latitude', '50.775')
# 2 ('longitude', '6.08333')
# 3 ('latitude', '56.18333')
# 4 ('longitude', '10.23333')
# 5 ('latitude', '54.21667')
# 6 ('longitude', '-113.0')
# 7 ('latitude', '16.88333')
# 8 ('longitude', '-99.9')
# 9 ('latitude', '-33.16667')
# 10 ('longitude', '-64.95')
# 11 ('latitude', '32.1')
# 12 ('longitude', '71.8')
# 13 ('latitude', '44.83333')
# 14 ('longitude', '95.16667')
# 15 ('latitude', '44.21667')
# 16 ('longitude', '0.61667')
# 17 ('latitude', '-31.6')
# 18 ('longitude', '-65.23333')
# 19 ('latitude', '-30.86667')
# 20 ('longitude', '-64.55')
# 21 ('latitude', '16.39806')
# 22 ('longitude', '-9.57028')
# 23 ('latitude', '19.08333')
# 24 ('longitude', '8.38333')
# 25 ('latitude', '50.66667')
# 26 ('longitude', '2.33333')
# 27 ('latitude', '29.51667')
# 28 ('longitude', '35.05')
# 29 ('latitude', '29.71667')
# 30 ('longitude', '77.95')
# 31 ('latitude', '8.91667')
# 32 ('longitude', '8.43333')
# 33 ('latitude', '39.91667')
# 34 ('longitude', '42.81667')
# 35 ('latitude', '24.41667')
# 36 ('longitude', '39.51667')
# 37 ('latitude', '13.66033')
# 38 ('longitude', '28.96')
# 39 ('latitude', '44.11667')
# 40 ('longitude', '4.08333')
# 41 ('latitude', '44.65')
# 42 ('longitude', '11.01667')
# 43 ('latitude', '2.0')
# 44 ('longitude', '22.66667')
# 45 ('latitude', '45.82133')
# 46 ('longitude', '6.01533')
# 47 ('latitude', '51.78333')
# 48 ('longitude', '-1.78333')
# 49 ('latitude', '36.23333')
# 50 ('longitude', '37.13333')
# 51 ('latitude', '44.88333')
# 52 ('longitude', '8.75')
# 53 ('latitude', '50.95')
# 54 ('longitude', '31.81667')
# 55 ('latitude', '45.26667')
# 56 ('longitude', '10.15')
# 57 ('latitude', '42.53333')
# 58 ('longitude', '-85.88333')
# 59 ('latitude', '26.96667')
# 60 ('longitude', '-105.31667')
# 61 ('latitude', '20.74575')
# 62 ('longitude', '32.41275')
# 63 ('latitude', '35.27333')
# 64 ('longitude', '44.21556')
# 65 ('latitude', '27.66667')
# 66 ('longitude', '78.25')
# 67 ('latitude', '26.58333')
# 68 ('longitude', '85.56667')
# 69 ('latitude', '44.61667')
# 70 ('longitude', '-70.75')
# 71 ('latitude', '48.7')
# 72 ('longitude', '37.5')
# 73 ('latitude', '20.88333')
# 74 ('longitude', '76.86667')
# 75 ('latitude', '0.0')
# 76 ('longitude', '0.0')
# 77 ('latitude', '47.46667')
# 78 ('longitude', '-0.55')
# 79 ('latitude', '-22.96667')
# 80 ('longitude', '-44.31667')
# 81 ('latitude', '9.53333')
# 82 ('longitude', '39.71667')
# 83 ('latitude', '25.15')
# 84 ('longitude', '105.18333')
# 85 ('latitude', '40.81056')
# 86 ('longitude', '140.78556')
# 87 ('latitude', '53.58333')
# 88 ('longitude', '-2.71667')
# 89 ('latitude', '43.86667')
# 90 ('longitude', '5.38333')
# 91 ('latitude', '-33.0')
# 92 ('longitude', '-66.0')
# 93 ('latitude', '38.5')
# 94 ('longitude', '-94.3')
# 95 ('latitude', '-31.41667')
# 96 ('longitude', '-60.66667')
# 97 ('latitude', '42.45')
# 98 ('longitude', '9.03333')
# 99 ('latitude', '31.805')
# 100 ('longitude', '-97.01')
# 101 ('latitude', '52.05')
# 102 ('longitude', '0.3')
# 103 ('latitude', '43.03333')
# 104 ('longitude', '12.55')
# 105 ('latitude', '25.25417')
# 106 ('longitude', '80.625')
# 107 ('latitude', '20.06667')
# 108 ('longitude', '-103.66667')
# 109 ('latitude', '34.75')
# 110 ('longitude', '-87.0')
# 111 ('latitude', '34.31667')
# 112 ('longitude', '-96.15')
# 113 ('latitude', '44.38333')
# 114 ('longitude', '5.16667')
# 115 ('latitude', '36.16667')
# 116 ('longitude', '3.66667')
# 117 ('latitude', '44.33333')
# 118 ('longitude', '3.23333')
# 119 ('latitude', '43.08333')
# 120 ('longitude', '0.58333')
# 121 ('latitude', '-21.46028')
# 122 ('longitude', '-49.95083')
# 123 ('latitude', '46.0')
# 124 ('longitude', '13.5')
# 125 ('latitude', '25.0')
# 126 ('longitude', '-103.5')
# 127 ('latitude', '2.71667')
# 128 ('longitude', '32.83333')
# 129 ('latitude', '36.8')
# 130 ('longitude', '-108.0')
# 131 ('latitude', '48.6')
# 132 ('longitude', '38.0')
# 133 ('latitude', '28.48333')
# 134 ('longitude', '78.5')
# 135 ('latitude', '35.96667')
# 136 ('longitude', '-82.48333')
# 137 ('latitude', '34.5')
# 138 ('longitude', '-88.66667')
# 139 ('latitude', '5.38333')
# 140 ('longitude', '16.38333')
# 141 ('latitude', '16.66667')
# 142 ('longitude', '101.18333')
# 143 ('latitude', '-6.91667')
# 144 ('longitude', '107.6')
# 145 ('latitude', '27.7')
# 146 ('longitude', '76.33333')
# 147 ('latitude', '30.4')
# 148 ('longitude', '78.2')
# 149 ('latitude', '-6.33333')
# 150 ('longitude', '106.0')
# 151 ('latitude', '43.95')
# 152 ('longitude', '-0.05')
# 153 ('latitude', '41.36667')
# 154 ('longitude', '2.16667')
# 155 ('latitude', '42.38333')
# 156 ('longitude', '-2.5')
# 157 ('latitude', '52.73333')
# 158 ('longitude', '84.08333')
# 159 ('latitude', '52.0')
# 160 ('longitude', '9.1')
# 161 ('latitude', '31.61667')
# 162 ('longitude', '76.8')
# 163 ('latitude', '52.56528')
# 164 ('longitude', '-1.33972')
# 165 ('latitude', '15.78333')
# 166 ('longitude', '-5.9')
# 167 ('latitude', '52.03333')
# 168 ('longitude', '20.93583')
# 169 ('latitude', '45.41667')
# 170 ('longitude', '-98.31667')
# 171 ('latitude', '38.25')
# 172 ('longitude', '-83.75')
# 173 ('latitude', '40.66813')
# 174 ('longitude', '-117.18913')
# 175 ('latitude', '11.08333')
# 176 ('longitude', '-0.18333')
# 177 ('latitude', '36.75')
# 178 ('longitude', '-93.5')
# 179 ('latitude', '39.8')
# 180 ('longitude', '-101.2')
# 181 ('latitude', '51.16667')
# 182 ('longitude', '-117.33333')
# 183 ('latitude', '53.01667')
# 184 ('longitude', '-4.1')
# 185 ('latitude', '33.6')
# 186 ('longitude', '-96.46667')
# 187 ('latitude', '-32.33333')
# 188 ('longitude', '-64.86667')
# 189 ('latitude', '25.36667')
# 190 ('longitude', '82.91667')
# 191 ('latitude', '32.25')
# 192 ('longitude', '-8.15')
# 193 ('latitude', '32.86667')
# 194 ('longitude', '10.8')
# 195 ('latitude', '39.08333')
# 196 ('longitude', '-89.15')
# 197 ('latitude', '-26.16667')
# 198 ('longitude', '28.41667')
# 199 ('latitude', '30.0')
# 200 ('longitude', '-7.0')
# 201 ('latitude', '45.95')
# 202 ('longitude', '-67.55')
# 203 ('latitude', '-31.91')
# 204 ('longitude', '-58.32833')
# 205 ('latitude', '11.65')
# 206 ('longitude', '-3.65')
# 207 ('latitude', '41.68333')
# 208 ('longitude', '-3.8')
# 209 ('latitude', '40.30583')
# 210 ('longitude', '-105.02325')
# 211 ('latitude', '42.53333')
# 212 ('longitude', '-73.83333')
# 213 ('latitude', '43.21667')
# 214 ('longitude', '-0.23333')
# 215 ('latitude', '33.88333')
# 216 ('longitude', '35.5')
# 217 ('latitude', '20.88333')
# 218 ('longitude', '74.83333')
# 219 ('latitude', '26.50833')
# 220 ('longitude', '73.11528')
# 221 ('latitude', '20.83333')
# 222 ('longitude', '71.46667')
# 223 ('latitude', '22.68333')
# 224 ('longitude', '90.65')
# 225 ('latitude', '22.08333')
# 226 ('longitude', '86.9')
# 227 ('latitude', '53.1')
# 228 ('longitude', '23.2')
# 229 ('latitude', '50.13333')
# 230 ('longitude', '27.16667')
# 231 ('latitude', '12.45')
# 232 ('longitude', '-0.08333')
# 233 ('latitude', '-33.15639')
# 234 ('longitude', '115.67639')
# 235 ('latitude', '13.76667')
# 236 ('longitude', '5.3')
# 237 ('latitude', '34.16667')
# 238 ('longitude', '-80.28333')
# 239 ('latitude', '25.38333')
# 240 ('longitude', '82.6')
# 241 ('latitude', '49.78333')
# 242 ('longitude', '30.16667')
# 243 ('latitude', '60.4')
# 244 ('longitude', '25.8')
# 245 ('latitude', '40.91667')
# 246 ('longitude', '-78.08333')
# 247 ('latitude', '36.83333')
# 248 ('longitude', '-97.33333')
# 249 ('latitude', '31.83333')
# 250 ('longitude', '-98.83333')
# 251 ('latitude', '49.36667')
# 252 ('longitude', '16.63333')
# 253 ('latitude', '40.48')
# 254 ('longitude', '-89.00417')
# 255 ('latitude', '33.83333')
# 256 ('longitude', '115.83333')
# 257 ('latitude', '23.0')
# 258 ('longitude', '-102.0')
# 259 ('latitude', '12.5')
# 260 ('longitude', '0.7')
# 261 ('latitude', '44.55')
# 262 ('longitude', '131.63333')
# 263 ('latitude', '44.86667')
# 264 ('longitude', '10.05')
# 265 ('latitude', '21.95')
# 266 ('longitude', '78.03333')
# 267 ('latitude', '54.23333')
# 268 ('longitude', '52.48333')
# 269 ('latitude', '48.15')
# 270 ('longitude', '24.28333')
# 271 ('latitude', '55.46667')
# 272 ('longitude', '35.86667')
# 273 ('latitude', '51.33333')
# 274 ('longitude', '33.88333')
# 275 ('latitude', '17.71067')
# 276 ('longitude', '-11.3715')
# 277 ('latitude', '17.17493')
# 278 ('longitude', '-11.34133')
# 279 ('latitude', '54.56667')
# 280 ('longitude', '-6.33333')
# 281 ('latitude', '40.5')
# 282 ('longitude', '-80.08333')
# 283 ('latitude', '50.6')
# 284 ('longitude', '16.3')
# 285 ('latitude', '50.66694')
# 286 ('longitude', '8.18361')
# 287 ('latitude', '53.4')
# 288 ('longitude', '9.1')
# 289 ('latitude', '52.13333')
# 290 ('longitude', '59.31667')
# 291 ('latitude', '53.9')
# 292 ('longitude', '-112.88333')
# 293 ('latitude', '39.77978')
# 294 ('longitude', '64.60035')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 c = 0
#       2 for record in data:
# ----> 3     for v in record['geolocation'].items():
#       4         c += 1
#       5         print(c, v)
#
# KeyError: 'geolocation'
